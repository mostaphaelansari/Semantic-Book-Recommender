# %%
import pandas as pd

books = pd.read_csv("books_with_categories.csv")

# %%
from transformers import pipeline
classifier = pipeline("text-classification",
                      model="j-hartmann/emotion-english-distilroberta-base",
                      top_k = None,
                      device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu"))
classifier("I am happy")
# Out:
# Device set to use cuda:0
# [[{'label': 'joy', 'score': 0.9657410383224487},
#   {'label': 'surprise', 'score': 0.016032403334975243},
#   {'label': 'sadness', 'score': 0.013527708128094673},
#   {'label': 'neutral', 'score': 0.002609465504065156},
#   {'label': 'anger', 'score': 0.0013809326337650418},
#   {'label': 'fear', 'score': 0.0003798551915679127},
#   {'label': 'disgust', 'score': 0.0003287669096607715}]]

# %%
books["description"][0]
print(books["description"][0])
classifier(books["description"][0])
# Out:
# A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.
# [[{'label': 'fear', 'score': 0.6548421382904053},
#   {'label': 'neutral', 'score': 0.16985152661800385},
#   {'label': 'sadness', 'score': 0.1164085641503334},
#   {'label': 'surprise', 'score': 0.02070065401494503},
#   {'label': 'disgust', 'score': 0.019100697711110115},
#   {'label': 'joy', 'score': 0.015161196701228619},
#   {'label': 'anger', 'score': 0.003935148008167744}]]

# %%
classifier(books["description"][0].split("."))
# Out:
# [[{'label': 'surprise', 'score': 0.7296030521392822},
#   {'label': 'neutral', 'score': 0.14038558304309845},
#   {'label': 'fear', 'score': 0.06816208362579346},
#   {'label': 'joy', 'score': 0.04794234037399292},
#   {'label': 'anger', 'score': 0.009156347252428532},
#   {'label': 'disgust', 'score': 0.0026284714695066214},
#   {'label': 'sadness', 'score': 0.0021221600472927094}],
#  [{'label': 'neutral', 'score': 0.449370801448822},
#   {'label': 'disgust', 'score': 0.27359145879745483},
#   {'label': 'joy', 'score': 0.1090829148888588},
#   {'label': 'sadness', 'score': 0.09362724423408508},
#   {'label': 'anger', 'score': 0.040478311479091644},
#   {'label': 'surprise', 'score': 0.026970181614160538},
#   {'label': 'fear', 'score': 0.006879045628011227}],
#  [{'label': 'neutral', 'score': 0.6462165713310242},
#   {'label': 'sadness', 'score': 0.2427327036857605},
#   {'label': 'disgust', 'score': 0.04342265799641609},
#   {'label': 'surprise', 'score': 0.02830052562057972},
#   {'label': 'joy', 'score': 0.014211485162377357},
#   {'label': 'fear', 'score': 0.014084113761782646},
#   {'label': 'anger', 'score': 0.011031907051801682}],
#  [{'label': 'fear', 'score': 0.9281678199768066},
#   {'label': 'anger', 'score': 0.032191094011068344},
#   {'label': 'neutral', 'score': 0.012808715924620628},
#   {'label': 'sadness', 'score': 0.008756887167692184},
#   {'label': 'surprise', 'score': 0.00859794206917286},
#   {'label': 'disgust', 'score': 0.008431847207248211},
#   {'label': 'joy', 'score': 0.0010455826995894313}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104170888662338},
#   {'label': 'disgust', 'score': 0.006480602081865072},
#   {'label': 'fear', 'score': 0.005394000560045242},
#   {'label': 'surprise', 'score': 0.0022869461681693792},
#   {'label': 'anger', 'score': 0.0018428928451612592},
#   {'label': 'joy', 'score': 0.001733880490064621}],
#  [{'label': 'joy', 'score': 0.9327971339225769},
#   {'label': 'disgust', 'score': 0.037717778235673904},
#   {'label': 'neutral', 'score': 0.01589195430278778},
#   {'label': 'sadness', 'score': 0.006444544997066259},
#   {'label': 'anger', 'score': 0.005025023128837347},
#   {'label': 'surprise', 'score': 0.0015812100609764457},
#   {'label': 'fear', 'score': 0.0005423100083135068}],
#  [{'label': 'joy', 'score': 0.6528704166412354},
#   {'label': 'neutral', 'score': 0.2542749345302582},
#   {'label': 'surprise', 'score': 0.06808308511972427},
#   {'label': 'sadness', 'score': 0.009908980689942837},
#   {'label': 'disgust', 'score': 0.0065122065134346485},
#   {'label': 'anger', 'score': 0.004821314942091703},
#   {'label': 'fear', 'score': 0.003529011970385909}],
#  [{'label': 'neutral', 'score': 0.5494767427444458},
#   {'label': 'sadness', 'score': 0.11169017851352692},
#   {'label': 'disgust', 'score': 0.10400668531656265},
#   {'label': 'surprise', 'score': 0.07876548916101456},
#   {'label': 'anger', 'score': 0.0641336441040039},
#   {'label': 'fear', 'score': 0.05136282369494438},
#   {'label': 'joy', 'score': 0.040564414113759995}]]

# %%
sentences = books["description"][0].split(".")
predictions = classifier(sentences)

# %%
sentences[0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives'

# %%
predictions[0]
# Out:
# [{'label': 'surprise', 'score': 0.7296030521392822},
#  {'label': 'neutral', 'score': 0.14038558304309845},
#  {'label': 'fear', 'score': 0.06816208362579346},
#  {'label': 'joy', 'score': 0.04794234037399292},
#  {'label': 'anger', 'score': 0.009156347252428532},
#  {'label': 'disgust', 'score': 0.0026284714695066214},
#  {'label': 'sadness', 'score': 0.0021221600472927094}]

# %%
sentences[3]
# Out:
# ' Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist'

# %%
predictions[3]
# Out:
# [{'label': 'fear', 'score': 0.9281678199768066},
#  {'label': 'anger', 'score': 0.032191094011068344},
#  {'label': 'neutral', 'score': 0.012808715924620628},
#  {'label': 'sadness', 'score': 0.008756887167692184},
#  {'label': 'surprise', 'score': 0.00859794206917286},
#  {'label': 'disgust', 'score': 0.008431847207248211},
#  {'label': 'joy', 'score': 0.0010455826995894313}]

# %%
predictions
# Out:
# [[{'label': 'surprise', 'score': 0.7296030521392822},
#   {'label': 'neutral', 'score': 0.14038558304309845},
#   {'label': 'fear', 'score': 0.06816208362579346},
#   {'label': 'joy', 'score': 0.04794234037399292},
#   {'label': 'anger', 'score': 0.009156347252428532},
#   {'label': 'disgust', 'score': 0.0026284714695066214},
#   {'label': 'sadness', 'score': 0.0021221600472927094}],
#  [{'label': 'neutral', 'score': 0.449370801448822},
#   {'label': 'disgust', 'score': 0.27359145879745483},
#   {'label': 'joy', 'score': 0.1090829148888588},
#   {'label': 'sadness', 'score': 0.09362724423408508},
#   {'label': 'anger', 'score': 0.040478311479091644},
#   {'label': 'surprise', 'score': 0.026970181614160538},
#   {'label': 'fear', 'score': 0.006879045628011227}],
#  [{'label': 'neutral', 'score': 0.6462165713310242},
#   {'label': 'sadness', 'score': 0.2427327036857605},
#   {'label': 'disgust', 'score': 0.04342265799641609},
#   {'label': 'surprise', 'score': 0.02830052562057972},
#   {'label': 'joy', 'score': 0.014211485162377357},
#   {'label': 'fear', 'score': 0.014084113761782646},
#   {'label': 'anger', 'score': 0.011031907051801682}],
#  [{'label': 'fear', 'score': 0.9281678199768066},
#   {'label': 'anger', 'score': 0.032191094011068344},
#   {'label': 'neutral', 'score': 0.012808715924620628},
#   {'label': 'sadness', 'score': 0.008756887167692184},
#   {'label': 'surprise', 'score': 0.00859794206917286},
#   {'label': 'disgust', 'score': 0.008431847207248211},
#   {'label': 'joy', 'score': 0.0010455826995894313}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104170888662338},
#   {'label': 'disgust', 'score': 0.006480602081865072},
#   {'label': 'fear', 'score': 0.005394000560045242},
#   {'label': 'surprise', 'score': 0.0022869461681693792},
#   {'label': 'anger', 'score': 0.0018428928451612592},
#   {'label': 'joy', 'score': 0.001733880490064621}],
#  [{'label': 'joy', 'score': 0.9327971339225769},
#   {'label': 'disgust', 'score': 0.037717778235673904},
#   {'label': 'neutral', 'score': 0.01589195430278778},
#   {'label': 'sadness', 'score': 0.006444544997066259},
#   {'label': 'anger', 'score': 0.005025023128837347},
#   {'label': 'surprise', 'score': 0.0015812100609764457},
#   {'label': 'fear', 'score': 0.0005423100083135068}],
#  [{'label': 'joy', 'score': 0.6528704166412354},
#   {'label': 'neutral', 'score': 0.2542749345302582},
#   {'label': 'surprise', 'score': 0.06808308511972427},
#   {'label': 'sadness', 'score': 0.009908980689942837},
#   {'label': 'disgust', 'score': 0.0065122065134346485},
#   {'label': 'anger', 'score': 0.004821314942091703},
#   {'label': 'fear', 'score': 0.003529011970385909}],
#  [{'label': 'neutral', 'score': 0.5494767427444458},
#   {'label': 'sadness', 'score': 0.11169017851352692},
#   {'label': 'disgust', 'score': 0.10400668531656265},
#   {'label': 'surprise', 'score': 0.07876548916101456},
#   {'label': 'anger', 'score': 0.0641336441040039},
#   {'label': 'fear', 'score': 0.05136282369494438},
#   {'label': 'joy', 'score': 0.040564414113759995}]]

# %%
sorted(predictions[0], key=lambda x: x["label"])
# Out:
# [{'label': 'anger', 'score': 0.009156347252428532},
#  {'label': 'disgust', 'score': 0.0026284714695066214},
#  {'label': 'fear', 'score': 0.06816208362579346},
#  {'label': 'joy', 'score': 0.04794234037399292},
#  {'label': 'neutral', 'score': 0.14038558304309845},
#  {'label': 'sadness', 'score': 0.0021221600472927094},
#  {'label': 'surprise', 'score': 0.7296030521392822}]

# %%
import numpy as np

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

def calculate_max_emotion_scores(predictions):
    per_emotion_scores = {label: [] for label in emotion_labels}
    for prediction in predictions:
        sorted_predictions = sorted(prediction, key=lambda x: x["label"])
        for index, label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_predictions[index]["score"])
    return {label: np.max(scores) for label, scores in per_emotion_scores.items()}

# %%
for i in range(10):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
emotion_scores
# Out:
# {'anger': [0.0641336441040039,
#   0.6126189231872559,
#   0.0641336441040039,
#   0.351483553647995,
#   0.08141225576400757,
#   0.2322245091199875,
#   0.5381837487220764,
#   0.0641336441040039,
#   0.3006700277328491,
#   0.0641336441040039],
#  'disgust': [0.27359145879745483,
#   0.3482850193977356,
#   0.10400668531656265,
#   0.1507224291563034,
#   0.1844949722290039,
#   0.7271751761436462,
#   0.1558549404144287,
#   0.10400668531656265,
#   0.27948129177093506,
#   0.17792807519435883],
#  'fear': [0.9281678199768066,
#   0.9425276517868042,
#   0.9723208546638489,
#   0.36070728302001953,
#   0.09504338353872299,
#   0.05136282369494438,
#   0.7474285364151001,
#   0.4044956564903259,
#   0.9155239462852478,
#   0.05136282369494438],
#  'joy': [0.9327971339225769,
#   0.7044206857681274,
#   0.7672367095947266,
#   0.25188109278678894,
#   0.040564414113759995,
#   0.04337586835026741,
#   0.8725652098655701,
#   0.040564414113759995,
#   0.040564414113759995,
#   0.040564414113759995],
#  'sadness': [0.6462165713310242,
#   0.887939453125,
#   0.5494767427444458,
#   0.7326856255531311,
#   0.8843895196914673,
#   0.6213922500610352,
#   0.7121943235397339,
#   0.5494767427444458,
#   0.8402893543243408,
#   0.8603722453117371],
#  'surprise': [0.9671575427055359,
#   0.11169017851352692,
#   0.11169017851352692,
#   0.11169017851352692,
#   0.47588086128234863,
#   0.11169017851352692,
#   0.40800008177757263,
#   0.8202826380729675,
#   0.3544600307941437,
#   0.11169017851352692],
#  'neutral': [0.7296030521392822,
#   0.252545028924942,
#   0.07876548916101456,
#   0.07876548916101456,
#   0.07876548916101456,
#   0.27190306782722473,
#   0.07876548916101456,
#   0.234487384557724,
#   0.13561421632766724,
#   0.07876548916101456]}

# %%
from tqdm import tqdm

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

for i in tqdm(range(len(books))):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# 100%|██████████| 5197/5197 [01:32<00:00, 56.23it/s]

# %%
emotions_df = pd.DataFrame(emotion_scores)
emotions_df["isbn13"] = isbn

# %%
emotions_df
# Out:
#          anger   disgust      fear       joy   sadness  surprise   neutral  \
# 0     0.064134  0.273591  0.928168  0.932797  0.646217  0.967158  0.729603
# 1     0.612619  0.348285  0.942528  0.704421  0.887939  0.111690  0.252545
# 2     0.064134  0.104007  0.972321  0.767237  0.549477  0.111690  0.078765
# 3     0.351484  0.150722  0.360707  0.251881  0.732686  0.111690  0.078765
# 4     0.081412  0.184495  0.095043  0.040564  0.884390  0.475881  0.078765
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148209  0.030643  0.919165  0.255169  0.853722  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400263  0.883198  0.111690  0.227765
# 5194  0.009997  0.009929  0.339218  0.947779  0.375755  0.066685  0.057625
# 5195  0.064134  0.104007  0.459270  0.759456  0.951104  0.368111  0.078765
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078765
#
#              isbn13
# 0     9780002005883
# 1     9780002261982
# 2     9780006178736
# 3     9780006280897
# 4     9780006280934
# ...             ...
# 5192  9788172235222
# 5193  9788173031014
# 5194  9788179921623
# 5195  9788185300535
# 5196  9789027712059
#
# [5197 rows x 8 columns]

# %%
books = pd.merge(books, emotions_df, on = "isbn13")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ...  \
# 0               3.85      247.0  ...
# 1               3.83      241.0  ...
# 2               3.93      512.0  ...
# 3               4.15      170.0  ...
# 4               4.09      176.0  ...
# ...              ...        ...  ...
# 5192            2.93      324.0  ...
# 5193            3.70      175.0  ...
# 5194            3.82      198.0  ...
# 5195            4.51      531.0  ...
# 5196            0.00      210.0  ...
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories  \
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
# ...                                                 ...               ...
# 5192  9788172235222 On A Train Journey Home To North...           Fiction
# 5193  9788173031014 This book tells the tale of a ma...        Nonfiction
# 5194  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5195  9788185300535 This collection of the timeless ...        Nonfiction
# 5196  9789027712059 Since the three volume edition o...        Nonfiction
#
#          anger   disgust      fear       joy   sadness  surprise   neutral
# 0     0.064134  0.273591  0.928168  0.932797  0.646217  0.967158  0.729603
# 1     0.612619  0.348285  0.942528  0.704421  0.887939  0.111690  0.252545
# 2     0.064134  0.104007  0.972321  0.767237  0.549477  0.111690  0.078765
# 3     0.351484  0.150722  0.360707  0.251881  0.732686  0.111690  0.078765
# 4     0.081412  0.184495  0.095043  0.040564  0.884390  0.475881  0.078765
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148209  0.030643  0.919165  0.255169  0.853722  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400263  0.883198  0.111690  0.227765
# 5194  0.009997  0.009929  0.339218  0.947779  0.375755  0.066685  0.057625
# 5195  0.064134  0.104007  0.459270  0.759456  0.951104  0.368111  0.078765
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078765
#
# [5197 rows x 21 columns]

# %%
books.to_csv("books_with_emotions.csv", index = False)
